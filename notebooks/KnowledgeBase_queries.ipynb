# %%
import cytopus as cp

# %%
G = cp.kb.KnowledgeBase()
# Out:
# KnowledgeBase object containing 75 cell types and 201 cellular processes

# %%
#list of all cell types in KnowledgeBase
G.celltypes
# Out:
# ['T-naive',
#  'p-DC',
#  'endo-lymphatic',
#  'NK',
#  'cDC3',
#  'CD8-T-progenitor-exhausted',
#  'CD56dim-NK',
#  'Lti',
#  'epi',
#  'plasma-blast',
#  'CD4-T',
#  'ILC',
#  'B-naive',
#  'FDC',
#  'ILC3',
#  'neutro',
#  'CD8-T_KLRG1pos-effector',
#  'carcinoma-cell',
#  'MDC',
#  'B-memory-DN',
#  'B-memory-switched',
#  'fibro',
#  'mono',
#  'cDC',
#  'endo-arterial',
#  'ILC3-NCRneg',
#  'Langerhans',
#  'endo',
#  'TEM',
#  'B-memory-non-switched',
#  'mast',
#  'Mac',
#  'T',
#  'CD8-T',
#  'baso',
#  'ILC2',
#  'gran',
#  'TSCM',
#  'colon-epi',
#  'DC',
#  'TRM',
#  'endo-aerocyte',
#  'eosino',
#  'lung-endo-venous',
#  'plasma',
#  'gdT',
#  'GC-B',
#  'capillary',
#  'B',
#  'CD56bright-NK',
#  'lung-epi',
#  'M',
#  'all-cells',
#  'B-memory',
#  'B-pb-mature',
#  'CD8-T_KLRG1neg-effector',
#  'ILC1',
#  'smooth-muscle',
#  'mo-DC',
#  'Treg',
#  'TFH',
#  'TCM',
#  'cDC2',
#  'B-pb-t1',
#  'ILC3-NCRpos',
#  'endo-systemic-venous',
#  'leukocyte',
#  'TNK',
#  'B-pb-t2',
#  'lung-smooth-muscle',
#  'crc-carcinoma-cell',
#  'NK-adaptive',
#  'NSCLC-carcinoma-cell',
#  'B-memory-IgM-MZ',
#  'cDC1']

# %%
#get successor of specific cell type
list(G.graph.successors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['DC']

# %%
list(G.graph.predecessors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['cDC1', 'cDC2', 'cDC3']

# %%
#dictionary of all cellular processes in KnowledgeBase as a dictionary {'process_1':['gene_a','gene_e','gene_y',...],'process_2':['gene_b','gene_u',...],...}
G.processes.keys()
# Out:
# dict_keys(['all_purine_metabolism', 'all_CYS_metabolism', 'fibro_IL4_response', 'NK_IL15_response', 'all_lipophagy', 'TNK_IL2-STAT5-signaling', 'all_posttranslation-modification', 'all_porphyrine-heme_metabolism', 'CD4-T_TH2_UP', 'all_MHC-I-presentation', 'DC_CD40L_response', 'all_Beta-Ala_metabolism', 'all_ALA-ASP_metabolism', 'all_coagulation-factor_production', 'all_ROS-detoxification', 'all_LYS_metabolism', 'all_steroid_metabolism', 'all_ethanol_metabolism', 'all_n-glycan_degradation', 'all_wnt-beta-catenin-signaling', 'all_autophagy-chaperone-mediated', 'all_transmembrane-transport-ER', 'all_heparan-sulfate_degradation', 'all_glutathione_metabolism', 'all_type-II-ifn-response', 'p-DC_CpG-TLR9_response', 'all_type-I-ifn-response', 'all_SASP', 'lung-epi_IL4_response', 'all_chondroitine-sulfate_degradation', 'DC_antigen-crosspresentation', 'all_MET_metabolism', 'all_n-glycan_synthesis', 'Treg_FoxP3-stabilization', 'TNK_PD-1_signaling', 'B_IL2_response', 'all_thiamin_metabolism', 'all_HIS_metabolism', 'all_hypoxia-response', 'all_glycerophospholipid_metabolism', 'all_complement_production', 'all_cholesterol-homeostasis', 'all_pentose-phosphate-pathway', 'all_TCA-cycle', 'all_triacylglycerol_synthesis', 'all_pyruvate_metabolism', 'all_galactose_metabolism', 'all_fatty-acid-beta-oxidation-peroxisomal', 'all_amino-sugar-nucleotide-sugar_metabolism', 'all_nucleotide_metabolism', 'all_protein-degradation-proteasome', 'all_platelet-activation-factor_production', 'all_JAK-STAT_signaling', 'all_transmembrane-transport-lysosome', 'all_glycolysis', 'all_ARG-PRO_metabolism', 'all_mitophagy', 'Mac_CSF1_response', 'all_fatty-acid-beta-oxidation-mitochondrial', 'all_fatty-acid_synthesis', 'M_IL17A_response', 'all_retinol_metabolism', 'all_osmotic-stress-response', 'all_keratan-sulfate_degradation', 'all_peroxisome-component', 'all_autophagy-selective', 'all_MYC_targets', 'CD8-T_IL12_response', 'all_NOD-like-receptor_signaling', 'all_fatty-acid-metabolism', 'Mac_LPS-IFNG_invitro_response', 'B_Breg_UP', 'all_autophagy_regulation_positive', 'all_transmembrane-transport-cellmembrane', 'all_PHE_metabolism', 'all_autophagy-nucleus', 'CD4-T_TH22_UP', 'T_tcr-activation', 'all_nucleophagy-late', 'all_G1S-transition', 'all_pyroptosis', 'all_biotin_metabolism', 'B_effector-2_UP', 'all_selenoamino-acid_metabolism', 'all_autophagy-peroxisome', 'CD4-T_TH17_UP', 'all_mitophagy_regulation_positive', 'all_fructose-mannose_metabolism', 'B_effector-1_UP', 'all_purine_synthesis', 'fibro_IL1B_response', 'all_folate_metabolism', 'all_histone-methylation', 'all_o-glycan_synthesis', 'all_microautophagy-lysosomal', 'all_DNA-demethylation', 'M_angiogenic-effectors', 'T_IL21_response', 'all_keratan-sulfate_synthesis', 'all_citric-acid-cycle', 'all_lactate_production', 'all_iron-uptake-and-storage', 'all_macroautophagy_regulation_positive', 'lung-smooth-muscle_TGFB1_response', 'B_CD40L_response', 'lung-epi_IL13_response', 'all_thrombolysis-factor_production', 'all_ketone-body_metabolism', 'all_inositol-phosphate_metabolism', 'T_IL4_response', 'leuko_transendothelial-migration', 'all_carnitine-shuttle', 'all_macroautophagy', 'all_pyrimidine_metabolism', 'all_bile-acid_synthesis', 'all_MHC-II-presentation', 'TNK_cytotoxicity-effectors', 'M_gran_CSF2_response', 'all_G2M-transition', 'all_chondroitine-and-heparan-sulfate_synthesis', 'all_propanoate_metabolism', 'all_circadian-rhythm', 'CD4-T_TH9_UP', 'leuko_ROS_production', 'all_IL6-JAK-STAT3_signaling', 'all_transmembrane-transport-golgi', 'all_DNA-repair', 'all_riboflavin_metabolism', 'all_ros_response', 'all_DNA-methylation', 'all_pyrimidine_synthesis', 'fibro_IL13_response', 'M_mac_CSF1_response', 'all_cytosolic-DNA-sensing_signaling', 'CD4-T_IL4_response', 'all_reticulophagy', 'all_TYR_metabolism', 'all_ascorbate-uptake', 'all_glycogenesis', 'all_pterin_synthesis', 'all_apoptosis', 'mast_granule-exocytosis', 'all_exocytosis', 'all_transmembrane-transport-mitochondrial', 'all_cholesterol_metabolism', 'all_xenobiotics ...

# %%
#dictionary of all cellular identities in KnowledgeBase as a dictionary {'identity_1':['gene_j','gene_k','gene_z',...],'identity_2':['gene_y','gene_p',...],...}
G.identities.keys()
# Out:
# dict_keys(['CD8-T-progenitor-exhausted', 'B-memory', 'B-memory-switched', 'FDC', 'cDC3', 'endo-aerocyte', 'T-naive', 'Treg', 'ILC2', 'capillary', 'B-pb-t2', 'p-DC', 'T', 'CD8-T_KLRG1neg-effector', 'Lti', 'mast', 'plasma', 'lung-endo-venous', 'Langerhans', 'TSCM', 'NK-adaptive', 'TEM', 'B', 'B-naive', 'ILC3-NCRpos', 'CD4-T', 'gran', 'CD56dim-NK', 'mo-DC', 'B-memory-DN', 'ILC1', 'mono', 'CD8-T_KLRG1pos-effector', 'CD8-T', 'GC-B', 'B-pb-t1', 'TCM', 'cDC2', 'B-pb-mature', 'B-memory-non-switched', 'B-memory-IgM-MZ', 'Mac', 'TRM', 'endo-systemic-venous', 'gdT', 'ILC3-NCRneg', 'plasma-blast', 'cDC1', 'CD56bright-NK', 'NK'])

# %%
#get genesets for a specific celltype
query_celltype = 'Treg'
gs_of_interest = [x[0] for x in G.filter_edges(attribute_name = 'class', attributes = ['process_OF'],target=query_celltype) if x[1]==query_celltype]
print('Gene sets directly related to celltype',query_celltype,'are:',gs_of_interest)
# Out:
# Gene sets directly related to celltype Treg are: ['Treg_FoxP3-stabilization']

# %%
#dictionary with gene set properties (for cellular processes or identities)
G.graph.nodes['all_macroautophagy_regulation_positive']
# Out:
# {'class': 'cellular_process',
#  'v.id': 'v_hs209',
#  'v.author': '10.5281/zenodo.2529950_210828',
#  'gst.name': 'manual_external',
#  'gsto.name': 'cell_death_autophagy'}

# %%
G.plot_celltypes()
# Out:
# all celltypes in knowledge base: ['T-naive', 'p-DC', 'endo-lymphatic', 'NK', 'cDC3', 'CD8-T-progenitor-exhausted', 'CD56dim-NK', 'Lti', 'epi', 'plasma-blast', 'CD4-T', 'ILC', 'B-naive', 'FDC', 'ILC3', 'neutro', 'CD8-T_KLRG1pos-effector', 'carcinoma-cell', 'MDC', 'B-memory-DN', 'B-memory-switched', 'fibro', 'mono', 'cDC', 'endo-arterial', 'ILC3-NCRneg', 'Langerhans', 'endo', 'TEM', 'B-memory-non-switched', 'mast', 'Mac', 'T', 'CD8-T', 'baso', 'ILC2', 'gran', 'TSCM', 'colon-epi', 'DC', 'TRM', 'endo-aerocyte', 'eosino', 'lung-endo-venous', 'plasma', 'gdT', 'GC-B', 'capillary', 'B', 'CD56bright-NK', 'lung-epi', 'M', 'all-cells', 'B-memory', 'B-pb-mature', 'CD8-T_KLRG1neg-effector', 'ILC1', 'smooth-muscle', 'mo-DC', 'Treg', 'TFH', 'TCM', 'cDC2', 'B-pb-t1', 'ILC3-NCRpos', 'endo-systemic-venous', 'leukocyte', 'TNK', 'B-pb-t2', 'lung-smooth-muscle', 'crc-carcinoma-cell', 'NK-adaptive', 'NSCLC-carcinoma-cell', 'B-memory-IgM-MZ', 'cDC1']

# %%
#you can open this file using your browser
G.plot_graph_interactive(attributes=['cell_type','cellular_process'],colors= ['red','blue'], save_path = 'graph.html')
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.

# %%
#this sometimes breaks the notebook, rather open the file using your browser outside of Jupyter
#from IPython.display import HTML
#HTML(filename='graph.html')

# %% [markdown]
# # create dictionary for Spectra

# %%
#if necessary convert cell type names to names in the KnowledgeBase
#e.g. B_GC would be the name for germinal center B cells in your data 
#but in the KnowledgeBase they are stored with a hyphon 'GC-B'

conversion_dict = {'B_GC':'GC-B',
 'B_memory':'B-memory',
 'B_naive': 'B-naive',
 'CD4_T':'CD4-T',
 'CD8_T':'CD8-T',
 'DC':'DC',
 'ILC3':'ILC',
 'MDC':'Mac',
 'NK':'NK',
 'Treg':'Treg',
 'gdT':'gdT',
 'mast':'mast',
 'pDC':'p-DC',
 'plasma':'plasma'}

#to map KnowledgeBase labels back to labels in data
conversion_dict_inv = {}
for i,v in conversion_dict.items():
    conversion_dict_inv[v]=i
conversion_dict_inv['global'] = 'global'

# %%
#define cell types to retrieve gene sets for
celltype_of_interest = ['B_GC',
 'B_memory',
 'B_naive',
 'CD4_T',
 'CD8_T',
 'DC',
 'ILC3',
 'MDC',
 'NK',
 'Treg',
 'gdT',
 'mast',
 'pDC',
 'plasma']
global_celltypes = ['all-cells','leukocyte']

celltype_of_interest = [conversion_dict[x] for x in celltype_of_interest]

#you can retrieve gene sets linked to the parents and children of the queried gene sets above
#you can define the query depth using a dictionary, for all cell types not defined in the dict the query depth of the 
#<parent_depth> parameter will be used (proceed equivalently for children using the <child_depth> and <child_depth_dict>
#parameters)

query_depth_parent = {'NK':2,'Treg':None,'DC':None} #e.g. removing the query for parent gene sets for Treg here because this would add the
                                #T-helper polarization gene sets (TH1, TH2, TH22 etc)
query_depth_child = {'CD4-T':None,'ILC':None}

#retrieve dictionary for Spectra
G.get_celltype_processes(celltype_of_interest,global_celltypes = global_celltypes,get_children=True,get_parents=True,
                         child_depth=1,parent_depth=1,parent_depth_dict = query_depth_parent,
                        child_depth_dict = query_depth_child)
# Out:
# cell types of interest share the following children: ['p-DC'] This may be desired.
# cell types of interest share the following parents: ['B', 'T', 'DC', 'ILC', 'TNK', 'M'] This may be desired.

# %%
#convert celltype labels back to celltypes in data
Spectra_dict = {}

for i,v in G.celltype_process_dict.items():
    Spectra_dict[conversion_dict_inv[i]] = v

# %%
Spectra_dict.keys()
# Out:
# dict_keys(['B_GC', 'B_memory', 'B_naive', 'CD4_T', 'CD8_T', 'DC', 'ILC3', 'MDC', 'NK', 'Treg', 'gdT', 'mast', 'pDC', 'plasma', 'global'])

# %%
Spectra_dict['CD4_T'].keys()
# Out:
# dict_keys(['CD4-T_TH2_UP', 'CD4-T_TH22_UP', 'CD4-T_TH17_UP', 'CD4-T_TH9_UP', 'CD4-T_IL4_response', 'CD4-T_TH1_UP', 'CD4-T_TFH_UP', 'CD4-T_IL12_response', 'T_tcr-activation', 'T_IL21_response', 'T_IL4_response'])

# %% [markdown]
# ## store and write to .json file

# %%
#store Spectra dictionary

import json
jpath = 'Spectra_dict.json'

with open(jpath, 'w') as f:
    json.dump(Spectra_dict,f)
print('saved data to:',jpath)
# Out:
# saved data to: Spectra_dict.json

# %%
#load Spectra dictionary

import json
jpath = 'Spectra_dict.json'
f = open(jpath, 'r')
Spectra_dict = json.loads(f.read())
