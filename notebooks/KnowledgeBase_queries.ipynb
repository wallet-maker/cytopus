# %%
import cytopus as cp

# %%
G = cp.kb.KnowledgeBase()
# Out:
# KnowledgeBase object containing 75 cell types and 201 cellular processes

# %%
#list of all cell types in KnowledgeBase
G.celltypes
# Out:
# ['NK-adaptive',
#  'carcinoma-cell',
#  'epi',
#  'lung-endo-venous',
#  'endo-arterial',
#  'B-memory-non-switched',
#  'TFH',
#  'endo-systemic-venous',
#  'FDC',
#  'fibro',
#  'cDC2',
#  'TSCM',
#  'p-DC',
#  'endo',
#  'M',
#  'TRM',
#  'mast',
#  'gran',
#  'GC-B',
#  'smooth-muscle',
#  'B-memory',
#  'gdT',
#  'Langerhans',
#  'ILC',
#  'CD8-T_KLRG1pos-effector',
#  'T-naive',
#  'TCM',
#  'eosino',
#  'B-memory-IgM-MZ',
#  'B-pb-mature',
#  'plasma',
#  'ILC1',
#  'lung-epi',
#  'mo-DC',
#  'NSCLC-carcinoma-cell',
#  'CD56dim-NK',
#  'all-cells',
#  'CD8-T',
#  'ILC2',
#  'B-pb-t2',
#  'colon-epi',
#  'cDC',
#  'B-memory-switched',
#  'B-naive',
#  'B-memory-DN',
#  'lung-smooth-muscle',
#  'Mac',
#  'neutro',
#  'TEM',
#  'ILC3-NCRneg',
#  'B-pb-t1',
#  'mono',
#  'MDC',
#  'endo-lymphatic',
#  'CD56bright-NK',
#  'endo-aerocyte',
#  'cDC3',
#  'baso',
#  'crc-carcinoma-cell',
#  'Lti',
#  'leukocyte',
#  'ILC3-NCRpos',
#  'NK',
#  'TNK',
#  'Treg',
#  'B',
#  'CD4-T',
#  'ILC3',
#  'DC',
#  'CD8-T-progenitor-exhausted',
#  'plasma-blast',
#  'capillary',
#  'T',
#  'CD8-T_KLRG1neg-effector',
#  'cDC1']

# %%
#get successor of specific cell type
list(G.graph.successors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['DC']

# %%
list(G.graph.predecessors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['cDC1', 'cDC2', 'cDC3']

# %%
#dictionary of all cellular processes in KnowledgeBase as a dictionary {'process_1':['gene_a','gene_e','gene_y',...],'process_2':['gene_b','gene_u',...],...}
G.processes.keys()
# Out:
# dict_keys(['all_selenoamino-acid_metabolism', 'Mac_IL4-IL13_response', 'TNK_cytotoxicity-effectors', 'CD4-T_TH9_UP', 'all_folate_metabolism', 'all_SASP', 'Treg_FoxP3-stabilization', 'all_CYP_metabolism', 'all_RIG-I-like-receptor_signaling', 'B_IL2_response', 'CD4-T_TH17_UP', 'all_DNA_synthesis', 'fibro_IL13_response', 'TNK_PD-1_signaling', 'all_microautophagy-lysosomal', 'all_pterin_synthesis', 'T_IL4_response', 'all_histone-methylation', 'all_transmembrane-transport-mitochondrial', 'all_multidrug-resistance', 'all_pyrimidine_metabolism', 'all_MHC-I-presentation', 'all_propanoate_metabolism', 'all_oxidative-phosphorylation', 'all_taurine-hypotaurine_metabolism', 'all_mTORC1_signaling', 'all_glycerophospholipid_metabolism', 'all_glycogenesis', 'all_nucleotide_metabolism', 'all_mitophagy_regulation_positive', 'all_glyoxylate-dicarboxylate_metabolism', 'all_wnt-beta-catenin-signaling', 'all_ARG-PRO_metabolism', 'lung-epi_IL13_response', 'all_n-glycan_degradation', 'CD4-T_TH1_UP', 'CD4-T_IL12_response', 'Mac_CSF1_response', 'all_inositol-phosphate_metabolism', 'NK_IL15_response', 'fibro_IL1B_response', 'all_NAD_metabolism', 'all_reticulophagy', 'all_transmembrane-transport-lysosome', 'all_G2M-transition', 'all_pentose-phosphate-pathway', 'all_IL6-JAK-STAT3_signaling', 'B_Breg_UP', 'all_JAK-STAT_signaling', 'all_TLR_signaling', 'leuko_transendothelial-migration', 'all_nucleophagy-late', 'lung-smooth-muscle_TGFB1_response', 'all_GPI-anchor_synthesis', 'all_cyclic-nucleotide_metabolism', 'all_citric-acid-cycle', 'all_keratan-sulfate_synthesis', 'leuko_ROS_production', 'all_cholesterol_metabolism', 'all_macroautophagy', 'M_mac_CSF1_response', 'all_ros_response', 'all_TYR_metabolism', 'DC_LPS_response', 'all_NOTCH_signaling', 'all_polyamines_metabolism', 'all_mitotic-spindle-component', 'all_autophagy-of-mitochondria', 'all_pyroptosis', 'CD4-T_TH22_UP', 'all_MHC-II-presentation', 'all_chondroitine-sulfate_degradation', 'T_IL21_response', 'all_exocytosis', 'all_CYS_metabolism', 'all_type-II-ifn-response', 'all_circadian-rhythm', 'all_PI3K-AKT-mTOR_signaling', 'all_glutathione_metabolism', 'all_TNF-via-NFkB_signaling', 'all_autophagy-nucleus', 'endo_VEGFC_response', 'all_osmotic-stress-response', 'endo_VEGFA_response', 'all_glycolysis', 'fibro_EGF_response', 'all_steroid_metabolism', 'all_type-I-ifn-response', 'all_ethanol_metabolism', 'all_lipophagy', 'all_purine_synthesis', 'CD4-T_TH2_UP', 'all_biotin_metabolism', 'all_CoA_synthesis', 'all_apoptosis', 'all_hyaluronan_metabolism', 'all_autophagy-chaperone-mediated', 'all_DNA-methylation', 'all_ROS-detoxification', 'all_cholesterol-homeostasis', 'all_phosphoinositide_signaling', 'all_keratan-sulfate_degradation', 'T_tcr-activation', 'all_glycerin-SER-THR_metabolism', 'all_VAL-LEU-ILE_metabolism', 'all_o-glycan_synthesis', 'all_LYS_metabolism', 'all_HIS_metabolism', 'lung-epi_IL17A-IL22_response', 'all_autophagy-of-mitochondria_regulation_positive', 'all_autophagic-cell-death', 'DC_CD40L_response', 'Mac_LPS_response', 'mast_granule-exocytosis', 'all_heparan-sulfate_degradation', 'B_IgM-ligation_response', 'all_TCA-cycle', 'all_pyruvate_metabolism', 'fibro_BMP4_response', 'all_TRP_metabolism', 'CD8-T_terminal-exhaustion', 'all_carnitine-shuttle', 'all_urea-cycle', 'M_angiogenic-effectors', 'p-DC_CpG-TLR9_response', 'CD4-T_TFH_UP', 'all_riboflavin_metabolism', 'all_n-glycan_synthesis', 'M_IL17A_response', 'all_amino-sugar-nucleotide-sugar_metabolism', 'all_DNA-demethylation', 'all_platelet-activation-factor_production', 'B_effector-1_UP', 'CD8-T_IL12_response', 'all_MET_metabolism', 'all_chondroitine-and-heparan-sulfate_synthesis', 'all_thiamin_metabolism', 'all_Beta-Ala_metabolism', 'all_PHE_metabolism', 'all_xenobiotics_metabolism', 'all_fatty-acid-metabolism', 'all_porphyrine-heme_metabolism', 'all_cytosolic-DNA-sensing_signaling', 'all_hedgehog_signaling', 'all_DNA-repair', 'all_iron-uptake-and-storage', 'all_ketone-body_metabolism', 'all_thrombolysis-factor_production', 'all_fatty-acid ...

# %%
#dictionary of all cellular identities in KnowledgeBase as a dictionary {'identity_1':['gene_j','gene_k','gene_z',...],'identity_2':['gene_y','gene_p',...],...}
G.identities.keys()
# Out:
# dict_keys(['B-memory-switched', 'CD8-T_KLRG1pos-effector', 'gdT', 'plasma-blast', 'mono', 'B-memory', 'B-memory-IgM-MZ', 'TRM', 'gran', 'ILC2', 'ILC3-NCRpos', 'FDC', 'B-pb-mature', 'lung-endo-venous', 'T-naive', 'cDC3', 'mast', 'endo-aerocyte', 'B-memory-DN', 'Mac', 'Lti', 'Langerhans', 'mo-DC', 'CD8-T-progenitor-exhausted', 'T', 'CD4-T', 'TCM', 'cDC1', 'p-DC', 'plasma', 'B-pb-t1', 'cDC2', 'ILC3-NCRneg', 'endo-systemic-venous', 'CD8-T_KLRG1neg-effector', 'TSCM', 'NK', 'TEM', 'Treg', 'NK-adaptive', 'B-memory-non-switched', 'CD8-T', 'CD56dim-NK', 'CD56bright-NK', 'B-naive', 'B-pb-t2', 'B', 'GC-B', 'capillary', 'ILC1'])

# %%
#get genesets for a specific celltype
query_celltype = 'Treg'
gs_of_interest = [x[0] for x in G.filter_edges(attribute_name = 'class', attributes = ['process_OF'],target=query_celltype) if x[1]==query_celltype]
print('Gene sets directly related to celltype',query_celltype,'are:',gs_of_interest)
# Out:
# Gene sets directly related to celltype Treg are: ['Treg_FoxP3-stabilization']

# %%
#dictionary with gene set properties (for cellular processes or identities)
G.graph.nodes['all_macroautophagy_regulation_positive']
# Out:
# {'class': 'cellular_process',
#  'v.id': 'v_hs209',
#  'v.author': '10.5281/zenodo.2529950_210828',
#  'gst.name': 'manual_external',
#  'gsto.name': 'cell_death_autophagy'}

# %%
G.plot_celltypes()
# Out:
# all celltypes in knowledge base: ['NK-adaptive', 'carcinoma-cell', 'epi', 'lung-endo-venous', 'endo-arterial', 'B-memory-non-switched', 'TFH', 'endo-systemic-venous', 'FDC', 'fibro', 'cDC2', 'TSCM', 'p-DC', 'endo', 'M', 'TRM', 'mast', 'gran', 'GC-B', 'smooth-muscle', 'B-memory', 'gdT', 'Langerhans', 'ILC', 'CD8-T_KLRG1pos-effector', 'T-naive', 'TCM', 'eosino', 'B-memory-IgM-MZ', 'B-pb-mature', 'plasma', 'ILC1', 'lung-epi', 'mo-DC', 'NSCLC-carcinoma-cell', 'CD56dim-NK', 'all-cells', 'CD8-T', 'ILC2', 'B-pb-t2', 'colon-epi', 'cDC', 'B-memory-switched', 'B-naive', 'B-memory-DN', 'lung-smooth-muscle', 'Mac', 'neutro', 'TEM', 'ILC3-NCRneg', 'B-pb-t1', 'mono', 'MDC', 'endo-lymphatic', 'CD56bright-NK', 'endo-aerocyte', 'cDC3', 'baso', 'crc-carcinoma-cell', 'Lti', 'leukocyte', 'ILC3-NCRpos', 'NK', 'TNK', 'Treg', 'B', 'CD4-T', 'ILC3', 'DC', 'CD8-T-progenitor-exhausted', 'plasma-blast', 'capillary', 'T', 'CD8-T_KLRG1neg-effector', 'cDC1']

# %%
#you can open this file using your browser
G.plot_graph_interactive(attributes=['cell_type','cellular_process'],colors= ['red','blue'], save_path = 'graph.html')
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.

# %%
#this sometimes breaks the notebook, rather open the file using your browser outside of Jupyter
#from IPython.display import HTML
#HTML(filename='graph.html')

# %% [markdown]
# # create dictionary for Spectra

# %%
#if necessary convert cell type names to names in the KnowledgeBase
#e.g. B_GC would be the name for germinal center B cells in your data 
#but in the KnowledgeBase they are stored with a hyphon 'GC-B'

conversion_dict = {'B_GC':'GC-B',
 'B_memory':'B-memory',
 'B_naive': 'B-naive',
 'CD4_T':'CD4-T',
 'CD8_T':'CD8-T',
 'DC':'DC',
 'ILC3':'ILC',
 'MDC':'Mac',
 'NK':'NK',
 'Treg':'Treg',
 'gdT':'gdT',
 'mast':'mast',
 'pDC':'p-DC',
 'plasma':'plasma'}

#to map KnowledgeBase labels back to labels in data
conversion_dict_inv = {}
for i,v in conversion_dict.items():
    conversion_dict_inv[v]=i
conversion_dict_inv['global'] = 'global'

# %%
#define cell types to retrieve gene sets for
celltype_of_interest = ['B_GC',
 'B_memory',
 'B_naive',
 'CD4_T',
 'CD8_T',
 'DC',
 'ILC3',
 'MDC',
 'NK',
 'Treg',
 'gdT',
 'mast',
 'pDC',
 'plasma']
global_celltypes = ['all-cells','leukocyte']

celltype_of_interest = [conversion_dict[x] for x in celltype_of_interest]

#you can retrieve gene sets linked to the parents and children of the queried gene sets above
#you can define the query depth using a dictionary, for all cell types not defined in the dict the query depth of the 
#<parent_depth> parameter will be used (proceed equivalently for children using the <child_depth> and <child_depth_dict>
#parameters)

query_depth_parent = {'NK':2,'Treg':None,'DC':None} #e.g. removing the query for parent gene sets for Treg here because this would add the
                                #T-helper polarization gene sets (TH1, TH2, TH22 etc)
query_depth_child = {'CD4-T':None,'ILC':None}

#retrieve dictionary for Spectra
G.get_celltype_processes(celltype_of_interest,global_celltypes = global_celltypes,get_children=True,get_parents=True,
                         child_depth=1,parent_depth=1,parent_depth_dict = query_depth_parent,
                        child_depth_dict = query_depth_child)
# Out:
# cell types of interest share the following children: ['p-DC'] This may be desired.
# cell types of interest share the following parents: ['B', 'T', 'DC', 'ILC', 'TNK', 'M'] This may be desired.

# %%
#convert celltype labels back to celltypes in data
Spectra_dict = {}

for i,v in G.celltype_process_dict.items():
    Spectra_dict[conversion_dict_inv[i]] = v

# %%
Spectra_dict.keys()
# Out:
# dict_keys(['B_GC', 'B_memory', 'B_naive', 'CD4_T', 'CD8_T', 'DC', 'ILC3', 'MDC', 'NK', 'Treg', 'gdT', 'mast', 'pDC', 'plasma', 'global'])

# %%
Spectra_dict['CD4_T'].keys()
# Out:
# dict_keys(['CD4-T_TH9_UP', 'CD4-T_TH17_UP', 'CD4-T_TH1_UP', 'CD4-T_IL12_response', 'CD4-T_TH22_UP', 'CD4-T_TH2_UP', 'CD4-T_TFH_UP', 'CD4-T_IL4_response', 'T_IL4_response', 'T_IL21_response', 'T_tcr-activation'])

# %% [markdown]
# ## store and write to .json file

# %%
#store Spectra dictionary

import json
jpath = 'Spectra_dict.json'

with open(jpath, 'w') as f:
    json.dump(Spectra_dict,f)
print('saved data to:',jpath)
# Out:
# saved data to: Spectra_dict.json

# %%
#load Spectra dictionary

import json
jpath = 'Spectra_dict.json'
f = open(jpath, 'r')
Spectra_dict = json.loads(f.read())
