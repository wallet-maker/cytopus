# %%
import cytopus as cp

# %%
G = cp.kb.KnowledgeBase()
# Out:
# KnowledgeBase object containing 75 cell types and 201 cellular processes

# %%
#list of all cell types in KnowledgeBase
G.celltypes
# Out:
# ['ILC2',
#  'cDC1',
#  'endo-lymphatic',
#  'TNK',
#  'gran',
#  'T',
#  'TEM',
#  'GC-B',
#  'CD8-T_KLRG1neg-effector',
#  'baso',
#  'cDC',
#  'NK-adaptive',
#  'CD4-T',
#  'endo-arterial',
#  'all-cells',
#  'smooth-muscle',
#  'FDC',
#  'B-pb-t1',
#  'Lti',
#  'ILC',
#  'lung-smooth-muscle',
#  'TCM',
#  'colon-epi',
#  'mast',
#  'endo',
#  'B-memory-non-switched',
#  'NSCLC-carcinoma-cell',
#  'B-pb-mature',
#  'Mac',
#  'Treg',
#  'plasma',
#  'cDC2',
#  'ILC3-NCRneg',
#  'crc-carcinoma-cell',
#  'B',
#  'fibro',
#  'CD8-T-progenitor-exhausted',
#  'NK',
#  'Langerhans',
#  'CD56bright-NK',
#  'eosino',
#  'B-memory-switched',
#  'DC',
#  'TFH',
#  'endo-systemic-venous',
#  'leukocyte',
#  'endo-aerocyte',
#  'ILC1',
#  'ILC3-NCRpos',
#  'mo-DC',
#  'TRM',
#  'plasma-blast',
#  'M',
#  'mono',
#  'carcinoma-cell',
#  'ILC3',
#  'CD8-T_KLRG1pos-effector',
#  'capillary',
#  'CD56dim-NK',
#  'TSCM',
#  'lung-epi',
#  'T-naive',
#  'epi',
#  'p-DC',
#  'B-memory',
#  'cDC3',
#  'gdT',
#  'MDC',
#  'B-pb-t2',
#  'B-naive',
#  'CD8-T',
#  'B-memory-DN',
#  'lung-endo-venous',
#  'B-memory-IgM-MZ',
#  'neutro']

# %%
#get successor of specific cell type
list(G.graph.successors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['DC']

# %%
list(G.graph.predecessors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['cDC1', 'cDC2', 'cDC3']

# %%
#dictionary of all cellular processes in KnowledgeBase as a dictionary {'process_1':['gene_a','gene_e','gene_y',...],'process_2':['gene_b','gene_u',...],...}
G.processes.keys()
# Out:
# dict_keys(['all_polyamines_metabolism', 'all_citric-acid-cycle', 'all_protein-degradation-proteasome', 'all_autophagic-cell-death', 'p-DC_CpG-TLR9_response', 'all_type-II-ifn-response', 'all_NAD_metabolism', 'TNK_cytotoxicity-effectors', 'all_porphyrine-heme_metabolism', 'fibro_EGF_response', 'all_glycogenolysis', 'T_tcr-activation', 'all_purine_metabolism', 'all_complement_production', 'lung-epi_IL4_response', 'all_heparan-sulfate_degradation', 'all_autophagy_regulation_positive', 'all_VAL-LEU-ILE_metabolism', 'all_exocytosis', 'all_NOTCH_signaling', 'all_CYP_metabolism', 'all_NOD-like-receptor_signaling', 'all_ROS-detoxification', 'all_transmembrane-transport-lysosome', 'all_autophagy-chaperone-mediated', 'all_DNA-methylation', 'all_type-I-ifn-response', 'B_CD40L_response', 'all_mTORC1_signaling', 'all_macroautophagy', 'all_lipophagy', 'all_MET_metabolism', 'all_CYS_metabolism', 'DC_antigen-crosspresentation', 'all_ALA-ASP_metabolism', 'all_TYR_metabolism', 'CD4-T_TH9_UP', 'all_circadian-rhythm', 'all_ARG-PRO_metabolism', 'CD4-T_TH22_UP', 'all_bile-acid_synthesis', 'all_o-glycan_synthesis', 'fibro_BMP4_response', 'all_biotin_metabolism', 'all_triacylglycerol_synthesis', 'all_PHE_metabolism', 'leuko_ROS_production', 'all_inositol-phosphate_metabolism', 'all_Beta-Ala_metabolism', 'all_taurine-hypotaurine_metabolism', 'all_SASP', 'all_retinol_metabolism', 'all_thiamin_metabolism', 'Mac_LPS-IFNG_invitro_response', 'M_mac_CSF1_response', 'all_unfolded-protein-response', 'all_reticulophagy', 'all_autophagy-of-mitochondria', 'all_keratan-sulfate_synthesis', 'M_gran_CSF2_response', 'all_microautophagy-lysosomal', 'fibro_IGF1_response', 'all_GPI-anchor_synthesis', 'all_histone-methylation', 'all_G2M-transition', 'all_lactate_production', 'all_galactose_metabolism', 'all_riboflavin_metabolism', 'all_platelet-activation-factor_production', 'all_LYS_metabolism', 'all_GLU_metabolism', 'all_transmembrane-transport-mitochondrial', 'fibro_IL1B_response', 'all_coagulation-factor_production', 'all_fatty-acid-beta-oxidation-peroxisomal', 'all_IL6-JAK-STAT3_signaling', 'B_IL2_response', 'all_mitotic-spindle-component', 'all_autophagy-peroxisome', 'all_fatty-acid_synthesis', 'all_glycolysis', 'all_HIS_metabolism', 'lung-smooth-muscle_TGFB1_response', 'all_macroautophagy_regulation_positive', 'CD4-T_TFH_UP', 'all_pyrimidine_metabolism', 'all_multidrug-resistance', 'all_glycogenesis', 'T_IL4_response', 'all_JAK-STAT_signaling', 'CD4-T_IL4_response', 'B_effector-2_UP', 'all_fructose-mannose_metabolism', 'all_xenobiotics_metabolism', 'all_ascorbate-uptake', 'TNK_IL2-STAT5-signaling', 'all_TNF-via-NFkB_signaling', 'all_cyclic-nucleotide_metabolism', 'all_folate_metabolism', 'fibro_IL4_response', 'all_fatty-acid-beta-oxidation-mitochondrial', 'all_oxidative-phosphorylation', 'all_GABA-shunt', 'all_cholesterol_metabolism', 'B_IgM-ligation_response', 'all_thrombolysis-factor_production', 'CD4-T_TH17_UP', 'all_chondroitine-sulfate_degradation', 'Mac_CSF1_response', 'all_phosphoinositide_signaling', 'all_sphingolipid_metabolism', 'all_glyoxylate-dicarboxylate_metabolism', 'NK_IL15_response', 'CD4-T_TH2_UP', 'all_CoA_synthesis', 'all_actin-cytoskeleton_regulation', 'all_fatty-acid-metabolism', 'lung-epi_IL13_response', 'all_nucleophagy-late', 'all_glycerophospholipid_metabolism', 'all_amino-sugar-nucleotide-sugar_metabolism', 'all_nucleotide_metabolism', 'all_apoptosis', 'DC_CD40L_response', 'all_ethanol_metabolism', 'all_posttranslation-modification', 'TNK_PD-1_signaling', 'fibro_TGFB1_response', 'fibro_IL13_response', 'T_IL21_response', 'all_pyroptosis', 'all_selenoamino-acid_metabolism', 'all_wnt-beta-catenin-signaling', 'CD4-T_IL12_response', 'all_cytosolic-DNA-sensing_signaling', 'Mac_IL4-IL13_response', 'all_p53-signaling', 'mast_granule-exocytosis', 'CD8-T_terminal-exhaustion', 'all_transmembrane-transport-cellmembrane', 'all_MYC_targets', 'all_RIG-I-like-receptor_signaling', 'all_MHC-I-presentation', 'all_DNA-repair', 'all_osmotic-stress-response', ...

# %%
#dictionary of all cellular identities in KnowledgeBase as a dictionary {'identity_1':['gene_j','gene_k','gene_z',...],'identity_2':['gene_y','gene_p',...],...}
G.identities.keys()
# Out:
# dict_keys(['T', 'CD8-T_KLRG1pos-effector', 'B-pb-mature', 'plasma-blast', 'NK', 'FDC', 'TEM', 'TSCM', 'B-naive', 'endo-aerocyte', 'Langerhans', 'NK-adaptive', 'cDC1', 'cDC2', 'B-pb-t2', 'mast', 'cDC3', 'B-pb-t1', 'CD8-T-progenitor-exhausted', 'B-memory-switched', 'gran', 'Treg', 'T-naive', 'p-DC', 'ILC3-NCRpos', 'lung-endo-venous', 'B-memory-DN', 'ILC1', 'capillary', 'TRM', 'CD56bright-NK', 'B-memory-non-switched', 'CD4-T', 'ILC3-NCRneg', 'gdT', 'B-memory', 'CD8-T_KLRG1neg-effector', 'Lti', 'GC-B', 'endo-systemic-venous', 'mo-DC', 'B', 'CD56dim-NK', 'Mac', 'mono', 'plasma', 'TCM', 'B-memory-IgM-MZ', 'ILC2', 'CD8-T'])

# %%
#get genesets for a specific celltype
query_celltype = 'Treg'
gs_of_interest = [x[0] for x in G.filter_edges(attribute_name = 'class', attributes = ['process_OF'],target=query_celltype) if x[1]==query_celltype]
print('Gene sets directly related to celltype',query_celltype,'are:',gs_of_interest)
# Out:
# Gene sets directly related to celltype Treg are: ['Treg_FoxP3-stabilization']

# %%
#dictionary with gene set properties (for cellular processes or identities)
G.graph.nodes['all_macroautophagy_regulation_positive']
# Out:
# {'class': 'cellular_process',
#  'v.id': 'v_hs209',
#  'v.author': '10.5281/zenodo.2529950_210828',
#  'gst.name': 'manual_external',
#  'gsto.name': 'cell_death_autophagy'}

# %%
G.plot_celltypes()
# Out:
# all celltypes in knowledge base: ['ILC2', 'cDC1', 'endo-lymphatic', 'TNK', 'gran', 'T', 'TEM', 'GC-B', 'CD8-T_KLRG1neg-effector', 'baso', 'cDC', 'NK-adaptive', 'CD4-T', 'endo-arterial', 'all-cells', 'smooth-muscle', 'FDC', 'B-pb-t1', 'Lti', 'ILC', 'lung-smooth-muscle', 'TCM', 'colon-epi', 'mast', 'endo', 'B-memory-non-switched', 'NSCLC-carcinoma-cell', 'B-pb-mature', 'Mac', 'Treg', 'plasma', 'cDC2', 'ILC3-NCRneg', 'crc-carcinoma-cell', 'B', 'fibro', 'CD8-T-progenitor-exhausted', 'NK', 'Langerhans', 'CD56bright-NK', 'eosino', 'B-memory-switched', 'DC', 'TFH', 'endo-systemic-venous', 'leukocyte', 'endo-aerocyte', 'ILC1', 'ILC3-NCRpos', 'mo-DC', 'TRM', 'plasma-blast', 'M', 'mono', 'carcinoma-cell', 'ILC3', 'CD8-T_KLRG1pos-effector', 'capillary', 'CD56dim-NK', 'TSCM', 'lung-epi', 'T-naive', 'epi', 'p-DC', 'B-memory', 'cDC3', 'gdT', 'MDC', 'B-pb-t2', 'B-naive', 'CD8-T', 'B-memory-DN', 'lung-endo-venous', 'B-memory-IgM-MZ', 'neutro']

# %%
#you can open this file using your browser
G.plot_graph_interactive(attributes=['cell_type','cellular_process'],colors= ['red','blue'], save_path = 'graph.html')
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.

# %%
#this sometimes breaks the notebook, rather open the file using your browser outside of Jupyter
#from IPython.display import HTML
#HTML(filename='graph.html')

# %% [markdown]
# # create dictionary for Spectra

# %%
#if necessary convert cell type names to names in the KnowledgeBase
#e.g. B_GC would be the name for germinal center B cells in your data 
#but in the KnowledgeBase they are stored with a hyphon 'GC-B'

conversion_dict = {'B_GC':'GC-B',
 'B_memory':'B-memory',
 'B_naive': 'B-naive',
 'CD4_T':'CD4-T',
 'CD8_T':'CD8-T',
 'DC':'DC',
 'ILC3':'ILC',
 'MDC':'Mac',
 'NK':'NK',
 'Treg':'Treg',
 'gdT':'gdT',
 'mast':'mast',
 'pDC':'p-DC',
 'plasma':'plasma'}

#to map KnowledgeBase labels back to labels in data
conversion_dict_inv = {}
for i,v in conversion_dict.items():
    conversion_dict_inv[v]=i
conversion_dict_inv['global'] = 'global'

# %%
#define cell types to retrieve gene sets for
celltype_of_interest = ['B_GC',
 'B_memory',
 'B_naive',
 'CD4_T',
 'CD8_T',
 'DC',
 'ILC3',
 'MDC',
 'NK',
 'Treg',
 'gdT',
 'mast',
 'pDC',
 'plasma']
global_celltypes = ['all-cells','leukocyte']

celltype_of_interest = [conversion_dict[x] for x in celltype_of_interest]

#you can retrieve gene sets linked to the parents and children of the queried gene sets above
#you can define the query depth using a dictionary, for all cell types not defined in the dict the query depth of the 
#<parent_depth> parameter will be used (proceed equivalently for children using the <child_depth> and <child_depth_dict>
#parameters)

query_depth_parent = {'NK':2,'Treg':None,'DC':None} #e.g. removing the query for parent gene sets for Treg here because this would add the
                                #T-helper polarization gene sets (TH1, TH2, TH22 etc)
query_depth_child = {'CD4-T':None,'ILC':None}

#retrieve dictionary for Spectra
G.get_celltype_processes(celltype_of_interest,global_celltypes = global_celltypes,get_children=True,get_parents=True,
                         child_depth=1,parent_depth=1,parent_depth_dict = query_depth_parent,
                        child_depth_dict = query_depth_child)
# Out:
# cell types of interest share the following children: ['p-DC'] This may be desired.
# cell types of interest share the following parents: ['B', 'T', 'DC', 'ILC', 'TNK', 'M'] This may be desired.

# %%
#convert celltype labels back to celltypes in data
Spectra_dict = {}

for i,v in G.celltype_process_dict.items():
    Spectra_dict[conversion_dict_inv[i]] = v

# %%
Spectra_dict.keys()
# Out:
# dict_keys(['B_GC', 'B_memory', 'B_naive', 'CD4_T', 'CD8_T', 'DC', 'ILC3', 'MDC', 'NK', 'Treg', 'gdT', 'mast', 'pDC', 'plasma', 'global'])

# %%
Spectra_dict['CD4_T'].keys()
# Out:
# dict_keys(['CD4-T_TH9_UP', 'CD4-T_TH22_UP', 'CD4-T_TFH_UP', 'CD4-T_IL4_response', 'CD4-T_TH17_UP', 'CD4-T_TH2_UP', 'CD4-T_IL12_response', 'CD4-T_TH1_UP', 'T_tcr-activation', 'T_IL4_response', 'T_IL21_response'])

# %% [markdown]
# ## store and write to .json file

# %%
#store Spectra dictionary

import json
jpath = 'Spectra_dict.json'

with open(jpath, 'w') as f:
    json.dump(Spectra_dict,f)
print('saved data to:',jpath)
# Out:
# saved data to: Spectra_dict.json

# %%
#load Spectra dictionary

import json
jpath = 'Spectra_dict.json'
f = open(jpath, 'r')
Spectra_dict = json.loads(f.read())
