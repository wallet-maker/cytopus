# %% [markdown]
# <a href="https://colab.research.google.com/github/wallet-maker/cytopus/blob/main/notebooks/KnowledgeBase_queries_colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install package

# %%
# !git clone https://github.com/wallet-maker/cytopus
# Out:
# fatal: destination path 'cytopus' already exists and is not an empty directory.

# %%
# !ls
# Out:
# cytopus  sample_data

# %%
# %cd cytopus
# Out:
# /content/cytopus

# %%
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/cytopus
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>1.3 in /usr/local/lib/python3.9/dist-packages (from cytopus==1.2) (1.5.3)
# Requirement already satisfied: numpy>1.2 in /usr/local/lib/python3.9/dist-packages (from cytopus==1.2) (1.22.4)
# Requirement already satisfied: matplotlib>3.4 in /usr/local/lib/python3.9/dist-packages (from cytopus==1.2) (3.7.1)
# Requirement already satisfied: networkx>2.7 in /usr/local/lib/python3.9/dist-packages (from cytopus==1.2) (3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>3.4->cytopus==1.2) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>3.4->cytopus==1.2) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>3.4->cytopus==1.2) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>3.4->cytopus==1.2) (23.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>3.4->cytopus==1.2) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>3.4->cytopus==1.2) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>3.4->cytopus==1.2) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>3.4->cytopus==1.2) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>3.4->cytopus==1.2) (8.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>1.3->cytopus==1.2) (2022.7.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>3.4->cytopus==1.2) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>3.4->cytopus==1.2) (1.16.0)
# Building wheels for collected packages: cytopus
#   Building wheel for cytopus (pyproject.toml) ... done
#   Created wheel for cytopus: filename=cytopus-1.2-py3-none-any.whl size=423183 sha256=bb545f913b4616645911ac76476e6c43e8f7bbbdca67ecd73243ad4c30b6b898
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zcwwy763/wheels/50/29/de/bc06e7e17ab46caa4c96ecf636cd686ba1f9f5d518ee3a4d9d
# Successfully built cytopus
# Installing collected packages: cytopus
#   Attempting uninstall: cytopus
#     Found existing installation: cytopus 1.2
#     Uninstalling cytopus-1.2:
#       Successfully uninstalled cytopus-1.2
# Successfully installed cytopus-1.2

# %%
#pygraphviz is required for plotting
# !apt install libgraphviz-dev
# !pip install pygraphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgraphviz-dev is already the newest version (2.42.2-3build2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pygraphviz in /usr/local/lib/python3.9/dist-packages (1.10)

# %%
#pyvis is required for plotting interactive graphs
# !pip install pyvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyvis in /usr/local/lib/python3.9/dist-packages (0.3.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from pyvis) (3.0.1)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.9/dist-packages (from pyvis) (3.1.2)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.9/dist-packages (from pyvis) (3.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (67.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=5.3.0->pyvis) (2.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2>=2.9.6->pyvis) (2.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.6)

# %% [markdown]
# # import packages

# %%
import cytopus as cp
import IPython

# %% [markdown]
# # Load and explore KnowledgeBase

# %%
G = cp.kb.KnowledgeBase()
# Out:
# KnowledgeBase object containing 75 cell types and 201 cellular processes

# %%
#list of all cell types in KnowledgeBase
G.celltypes
# Out:
# ['gran',
#  'baso',
#  'Treg',
#  'Langerhans',
#  'FDC',
#  'GC-B',
#  'all-cells',
#  'mo-DC',
#  'B-memory-switched',
#  'B-memory-IgM-MZ',
#  'ILC2',
#  'mast',
#  'cDC1',
#  'neutro',
#  'M',
#  'CD8-T_KLRG1pos-effector',
#  'cDC2',
#  'endo-aerocyte',
#  'MDC',
#  'B-memory-non-switched',
#  'NSCLC-carcinoma-cell',
#  'TRM',
#  'B',
#  'NK-adaptive',
#  'B-memory-DN',
#  'Lti',
#  'fibro',
#  'ILC',
#  'epi',
#  'ILC3',
#  'eosino',
#  'CD56bright-NK',
#  'B-memory',
#  'CD4-T',
#  'TNK',
#  'carcinoma-cell',
#  'ILC3-NCRpos',
#  'TSCM',
#  'leukocyte',
#  'T-naive',
#  'plasma-blast',
#  'plasma',
#  'B-naive',
#  'ILC1',
#  'lung-endo-venous',
#  'crc-carcinoma-cell',
#  'lung-smooth-muscle',
#  'TFH',
#  'colon-epi',
#  'ILC3-NCRneg',
#  'TCM',
#  'gdT',
#  'endo-lymphatic',
#  'TEM',
#  'Mac',
#  'endo',
#  'B-pb-mature',
#  'cDC',
#  'B-pb-t2',
#  'CD8-T',
#  'CD8-T_KLRG1neg-effector',
#  'endo-systemic-venous',
#  'B-pb-t1',
#  'mono',
#  'NK',
#  'T',
#  'CD8-T-progenitor-exhausted',
#  'smooth-muscle',
#  'cDC3',
#  'capillary',
#  'endo-arterial',
#  'lung-epi',
#  'p-DC',
#  'CD56dim-NK',
#  'DC']

# %%
#plot the cell type hierarchy
G.plot_celltypes()
# Out:
# all celltypes in knowledge base: ['gran', 'baso', 'Treg', 'Langerhans', 'FDC', 'GC-B', 'all-cells', 'mo-DC', 'B-memory-switched', 'B-memory-IgM-MZ', 'ILC2', 'mast', 'cDC1', 'neutro', 'M', 'CD8-T_KLRG1pos-effector', 'cDC2', 'endo-aerocyte', 'MDC', 'B-memory-non-switched', 'NSCLC-carcinoma-cell', 'TRM', 'B', 'NK-adaptive', 'B-memory-DN', 'Lti', 'fibro', 'ILC', 'epi', 'ILC3', 'eosino', 'CD56bright-NK', 'B-memory', 'CD4-T', 'TNK', 'carcinoma-cell', 'ILC3-NCRpos', 'TSCM', 'leukocyte', 'T-naive', 'plasma-blast', 'plasma', 'B-naive', 'ILC1', 'lung-endo-venous', 'crc-carcinoma-cell', 'lung-smooth-muscle', 'TFH', 'colon-epi', 'ILC3-NCRneg', 'TCM', 'gdT', 'endo-lymphatic', 'TEM', 'Mac', 'endo', 'B-pb-mature', 'cDC', 'B-pb-t2', 'CD8-T', 'CD8-T_KLRG1neg-effector', 'endo-systemic-venous', 'B-pb-t1', 'mono', 'NK', 'T', 'CD8-T-progenitor-exhausted', 'smooth-muscle', 'cDC3', 'capillary', 'endo-arterial', 'lung-epi', 'p-DC', 'CD56dim-NK', 'DC']

# %%
#you can open this file using your browser (will not be displayed in colab)
G.plot_graph_interactive(attributes=['cell_type','cellular_process'],colors= ['red','blue'], save_path = 'graph.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# graph.html

# %%
# !ls
# Out:
# cytopus     img  LICENSE    pyproject.toml  setup.py
# graph.html  lib  notebooks  README.md	    Spectra_dict.json

# %%
#get parent in the hierarchy of specific cell type
list(G.graph.successors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['DC']

# %%
#get child in the hierarchy of a specific cell type
list(G.graph.predecessors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['cDC1', 'cDC2', 'cDC3']

# %%
#dictionary of all cellular processes in KnowledgeBase as a dictionary {'process_1':['gene_a','gene_e','gene_y',...],'process_2':['gene_b','gene_u',...],...}
G.processes.keys()
# Out:
# dict_keys(['lung-epi_IL4_response', 'all_carnitine-shuttle', 'fibro_IGF1_response', 'p-DC_CpG-TLR9_response', 'all_autophagy_regulation_positive', 'B_IL2_response', 'all_SASP', 'all_fatty-acid-beta-oxidation-mitochondrial', 'all_PI3K-AKT-mTOR_signaling', 'all_eicosanoid_metabolism', 'all_lactate_production', 'all_citric-acid-cycle', 'T_tcr-activation', 'all_polyamines_metabolism', 'all_taurine-hypotaurine_metabolism', 'all_ARG-PRO_metabolism', 'leuko_ROS_production', 'CD4-T_IL12_response', 'B_CD40L_response', 'all_microautophagy-lysosomal', 'all_glycolysis', 'M_gran_CSF2_response', 'Mac_IL4-IL13_response', 'all_transmembrane-transport-mitochondrial', 'CD4-T_TH9_UP', 'lung-smooth-muscle_TGFB1_response', 'all_GPI-anchor_synthesis', 'M_IL17A_response', 'all_fructose-mannose_metabolism', 'all_selenoamino-acid_metabolism', 'Mac_LPS-IFNG_invitro_response', 'mast_granule-exocytosis', 'all_DNA-demethylation', 'all_n-glycan_degradation', 'all_pyrimidine_synthesis', 'all_purine_metabolism', 'all_CoA_synthesis', 'all_autophagy-of-mitochondria', 'all_mitophagy', 'all_autophagy-peroxisome', 'all_ros_response', 'all_transmembrane-transport-golgi', 'T_IL21_response', 'all_protein-degradation-proteasome', 'all_keratan-sulfate_synthesis', 'B_effector-1_UP', 'T_IL4_response', 'all_G2M-transition', 'all_urea-cycle', 'B_Breg_UP', 'DC_LPS_response', 'fibro_EGF_response', 'CD4-T_TFH_UP', 'all_macroautophagy', 'all_thiamin_metabolism', 'all_fatty-acid_synthesis', 'all_TLR_signaling', 'all_chondroitine-sulfate_degradation', 'fibro_TGFB1_response', 'all_G1S-transition', 'all_circadian-rhythm', 'all_fatty-acid-metabolism', 'all_TYR_metabolism', 'lung-epi_IL17A-IL22_response', 'all_cytosolic-DNA-sensing_signaling', 'all_bile-acid_synthesis', 'all_triacylglycerol_synthesis', 'Mac_CSF1_response', 'all_pterin_synthesis', 'all_oxidative-phosphorylation', 'all_autophagy-nucleus', 'CD8-T_terminal-exhaustion', 'DC_antigen-crosspresentation', 'CD4-T_IL4_response', 'all_glutathione_metabolism', 'TNK_IL2_response', 'all_cyclic-nucleotide_metabolism', 'all_hyaluronan_metabolism', 'lung-epi_IL13_response', 'CD4-T_TH22_UP', 'all_mitotic-spindle-component', 'all_complement_production', 'all_multidrug-resistance', 'all_autophagy-of-mitochondria_regulation_positive', 'all_folate_metabolism', 'fibro_IL4_response', 'all_retinol_metabolism', 'all_type-I-ifn-response', 'all_LYS_metabolism', 'all_glycerin-SER-THR_metabolism', 'all_sphingolipid_metabolism', 'all_phosphoinositide_signaling', 'all_ketone-body_metabolism', 'all_pyroptosis', 'all_wnt-beta-catenin-signaling', 'all_keratan-sulfate_degradation', 'all_PHE_metabolism', 'all_ubiquinone_synthesis', 'all_type-II-ifn-response', 'all_HIS_metabolism', 'all_NOD-like-receptor_signaling', 'all_MHC-II-presentation', 'all_biotin_metabolism', 'TNK_PD-1_signaling', 'fibro_IL13_response', 'all_platelet-activation-factor_production', 'CD4-T_TH1_UP', 'all_porphyrine-heme_metabolism', 'all_coagulation-factor_production', 'all_NAD_metabolism', 'all_TNF-via-NFkB_signaling', 'TNK_cytotoxicity-effectors', 'all_glycogenolysis', 'B_effector-2_UP', 'all_NOTCH_signaling', 'all_thrombolysis-factor_production', 'all_lipophagy', 'all_fatty-acid-beta-oxidation-peroxisomal', 'all_chondroitine-and-heparan-sulfate_synthesis', 'all_MET_metabolism', 'all_ethanol_metabolism', 'all_RIG-I-like-receptor_signaling', 'all_MHC-I-presentation', 'CD8-T_IL12_response', 'TNK_IL2-STAT5-signaling', 'all_riboflavin_metabolism', 'all_p53-signaling', 'all_steroid_metabolism', 'all_DNA_synthesis', 'all_pyrimidine_metabolism', 'all_autophagic-cell-death', 'all_o-glycan_synthesis', 'all_transmembrane-transport-ER', 'all_cholesterol-homeostasis', 'B_IgM-ligation_response', 'all_transmembrane-transport-cellmembrane', 'all_propanoate_metabolism', 'all_ROS-detoxification', 'all_posttranslation-modification', 'CD4-T_TH2_UP', 'M_mac_CSF1_response', 'all_autophagy-selective', 'fibro_BMP4_response', 'all_nucleophagy-late', 'all_TCA-cycle', 'all_iron-uptake-and-storage', 'all_V ...

# %%
#dictionary of all cellular identities in KnowledgeBase as a dictionary {'identity_1':['gene_j','gene_k','gene_z',...],'identity_2':['gene_y','gene_p',...],...}
G.identities.keys()
# Out:
# dict_keys(['TCM', 'TSCM', 'CD8-T_KLRG1pos-effector', 'TEM', 'FDC', 'Langerhans', 'B-memory-DN', 'Treg', 'B-memory-non-switched', 'CD56bright-NK', 'mono', 'B-pb-t1', 'NK-adaptive', 'mast', 'TRM', 'CD4-T', 'cDC2', 'p-DC', 'GC-B', 'B-memory-IgM-MZ', 'CD8-T', 'NK', 'T', 'ILC2', 'mo-DC', 'capillary', 'endo-systemic-venous', 'cDC3', 'B', 'gran', 'CD56dim-NK', 'cDC1', 'B-pb-t2', 'Lti', 'plasma', 'B-pb-mature', 'gdT', 'plasma-blast', 'CD8-T-progenitor-exhausted', 'Mac', 'B-memory-switched', 'ILC1', 'ILC3-NCRpos', 'CD8-T_KLRG1neg-effector', 'lung-endo-venous', 'ILC3-NCRneg', 'B-memory', 'endo-aerocyte', 'T-naive', 'B-naive'])

# %%
#get genesets for a specific celltype
query_celltype = 'Treg'
gs_of_interest = [x[0] for x in G.filter_edges(attribute_name = 'class', attributes = ['process_OF'],target=query_celltype) if x[1]==query_celltype]
print('Gene sets directly related to celltype',query_celltype,'are:',gs_of_interest)
# Out:
# Gene sets directly related to celltype Treg are: ['Treg_FoxP3-stabilization']

# %%
#dictionary with gene set properties (for cellular processes or identities)

print('here external gene set from GO:')
print(G.graph.nodes['all_macroautophagy_regulation_positive'])

print('here manually curated gene set by the package author:')
print(G.graph.nodes['Mac_LPS_response'])
# Out:
# here external gene set from GO:
# {'class': 'cellular_process', 'v.id': 'v_hs209', 'v.author': '10.5281/zenodo.2529950_210828', 'gst.name': 'manual_external', 'gsto.name': 'cell_death_autophagy', 'size': 10}
# here manually curated gene set by the package author:
# {'class': 'cellular_process', 'v.id': 'v_hs230', 'v.author': 'wallet', 'gst.name': 'bulk_curated', 'gsto.name': 'immune_cellular_response', 'size': 10}

# %%
#get genesets for a specific celltype
query_celltype = 'Treg'
gs_of_interest = [x[0] for x in G.filter_edges(attribute_name = 'class', attributes = ['process_OF'],target=query_celltype) if x[1]==query_celltype]
print('Gene sets directly related to celltype',query_celltype,'are:',gs_of_interest)
# Out:
# Gene sets directly related to celltype Treg are: ['Treg_FoxP3-stabilization']

# %% [markdown]
# # Create a dictionary for Spectra

# %%
#if necessary convert cell type names to names in the KnowledgeBase
#e.g. B_GC would be the name for germinal center B cells in your data 
#but in the KnowledgeBase they are stored with a hyphon 'GC-B'

conversion_dict = {'B_GC':'GC-B',
 'B_memory':'B-memory',
 'B_naive': 'B-naive',
 'CD4_T':'CD4-T',
 'CD8_T':'CD8-T',
 'DC':'DC',
 'ILC3':'ILC',
 'MDC':'Mac',
 'NK':'NK',
 'Treg':'Treg',
 'gdT':'gdT',
 'mast':'mast',
 'pDC':'p-DC',
 'plasma':'plasma'}

#to map KnowledgeBase labels back to labels in data
conversion_dict_inv = {}
for i,v in conversion_dict.items():
    conversion_dict_inv[v]=i
conversion_dict_inv['global'] = 'global'

# %%
#define cell types to retrieve gene sets for
celltype_of_interest = ['B_GC',
 'B_memory',
 'B_naive',
 'CD4_T',
 'CD8_T',
 'DC',
 'ILC3',
 'MDC',
 'NK',
 'Treg',
 'gdT',
 'mast',
 'pDC',
 'plasma']
global_celltypes = ['all-cells','leukocyte']

celltype_of_interest = [conversion_dict[x] for x in celltype_of_interest]

#you can retrieve gene sets linked to the parents and children of the queried gene sets above
#you can define the query depth using a dictionary, for all cell types not defined in the dict the query depth of the 
#<parent_depth> parameter will be used (proceed equivalently for children using the <child_depth> and <child_depth_dict>
#parameters)

query_depth_parent = {'NK':2,'Treg':None,'DC':None} #e.g. removing the query for parent gene sets for Treg here because this would add the
                                #T-helper polarization gene sets (TH1, TH2, TH22 etc)
query_depth_child = {'CD4-T':None,'ILC':None}

#retrieve dictionary for Spectra
G.get_celltype_processes(celltype_of_interest,global_celltypes = global_celltypes,get_children=True,get_parents=True,
                         child_depth=1,parent_depth=1,parent_depth_dict = query_depth_parent,
                        child_depth_dict = query_depth_child)
# Out:
# cell types of interest share the following children: ['p-DC'] This may be desired.
# cell types of interest share the following parents: ['B', 'T', 'DC', 'ILC', 'TNK', 'M'] This may be desired.

# %%
#convert celltype labels back to celltypes in data
Spectra_dict = {}

for i,v in G.celltype_process_dict.items():
    Spectra_dict[conversion_dict_inv[i]] = v

# %%
Spectra_dict.keys()
# Out:
# dict_keys(['B_GC', 'B_memory', 'B_naive', 'CD4_T', 'CD8_T', 'DC', 'ILC3', 'MDC', 'NK', 'Treg', 'gdT', 'mast', 'pDC', 'plasma', 'global'])

# %%
Spectra_dict['CD4_T'].keys()
# Out:
# dict_keys(['CD4-T_IL12_response', 'CD4-T_TH9_UP', 'CD4-T_TFH_UP', 'CD4-T_IL4_response', 'CD4-T_TH22_UP', 'CD4-T_TH1_UP', 'CD4-T_TH2_UP', 'CD4-T_TH17_UP', 'T_tcr-activation', 'T_IL21_response', 'T_IL4_response'])

# %% [markdown]
# ## Write dictionary to .json file

# %%
#store Spectra dictionary

import json
jpath = 'Spectra_dict.json'

with open(jpath, 'w') as f:
    json.dump(Spectra_dict,f)
print('saved data to:',jpath)
# Out:
# saved data to: Spectra_dict.json

# %%
#load Spectra dictionary

import json
jpath = 'Spectra_dict.json'
f = open(jpath, 'r')
Spectra_dict = json.loads(f.read())
