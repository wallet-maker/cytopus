# %% [markdown]
# <a href="https://colab.research.google.com/github/wallet-maker/cytopus/blob/main/notebooks/KnowledgeBase_queries_colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install package

# %%
pip install cytopus
# Out:
# Cloning into 'cytopus'...
# remote: Enumerating objects: 338, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 338 (delta 24), reused 23 (delta 15), pack-reused 296
# Receiving objects: 100% (338/338), 51.47 MiB | 9.18 MiB/s, done.
# Resolving deltas: 100% (156/156), done.

# %%
#pygraphviz is required for plotting
# !apt install libgraphviz-dev
# !pip install pygraphviz
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# Requirement already satisfied: pygraphviz in /home/wallet/miniconda3/envs/2023_cytopus/lib/python3.10/site-packages (1.9)

# %%
#pyvis is required for plotting interactive graphs
# !pip install pyvis
# Out:
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ipython>=5.3.0 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from pyvis) (8.27.0)
# Collecting jinja2>=2.9.6 (from pyvis)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Downloading jsonpickle-3.3.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: networkx>=1.11 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from pyvis) (3.3)
# Requirement already satisfied: decorator in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis) (2.18.0)
# Requirement already satisfied: stack-data in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9.6->pyvis)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.4.1)
# Requirement already satisfied: pure-eval in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /home/wallet/miniconda3/envs/2024_cytopus_test_3/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 7.5 MB/s eta 0:00:00
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading jsonpickle-3.3.0-py3-none-any.whl (42 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Installing collected packages: MarkupSafe, jsonpickle, jinja2, pyvis
# Successfully installed MarkupSafe-2.1.5 jinja2-3.1.4 jsonpickle-3.3.0 pyvis-0.3.2

# %% [markdown]
# # import packages

# %%
import cytopus as cp
import IPython

# %% [markdown]
# # Load and explore KnowledgeBase

# %%
G = cp.KnowledgeBase()
# Out:
# KnowledgeBase object containing 92 cell types and 201 cellular processes

# %%
#number of cellular identity gene sets
len(G.identities.keys())
# Out:
# 53

# %%
#get genesets for a specific celltype
query_celltype = 'M'
gs_of_interest = [x[0] for x in G.filter_edges(attribute_name = 'class', attributes = ['process_OF'],target=query_celltype) if x[1]==query_celltype]
print('Gene sets directly related to celltype',query_celltype,'are:',gs_of_interest)
# Out:
# Gene sets directly related to celltype M are: ['M_IL17A_response', 'M_mac_CSF1_response', 'M_angiogenic-effectors']

# %%
#list of all cell types in KnowledgeBase
G.celltypes
# Out:
# ['CD8-T_terminal-exhaustion',
#  'endo-arterial',
#  'ILC1',
#  'TCM',
#  'baso',
#  'T-naive',
#  'ILC',
#  'gran',
#  'cDC3',
#  'cDC',
#  'endo-lymphatic',
#  'ILC3-NCRpos',
#  'lung-endo-venous',
#  'Lti',
#  'CD8-TSCM',
#  'CD56dim-NK',
#  'neutro',
#  'lung-smooth-muscle',
#  'endo-systemic-venous',
#  'crc-carcinoma-cell',
#  'p-DC',
#  'B-memory-switched',
#  'all-cells',
#  'colon-epi',
#  'ILC3',
#  'CD4-TSCM',
#  'B-memory-non-switched',
#  'iNKT',
#  'capillary',
#  'CD4-TEM',
#  'GC-B',
#  'Mac',
#  'CD8-TCM',
#  'cDC1',
#  'B-naive',
#  'B-pb-mature',
#  'CD8-Teffector',
#  'CD8-T-progenitor-exhausted',
#  'TSCM',
#  'fibro',
#  'endo',
#  'T',
#  'DC',
#  'NSCLC-carcinoma-cell',
#  'B-pb-t2',
#  'B-memory',
#  'MAIT',
#  'plasma-blast',
#  'mono',
#  'Treg',
#  'MDC',
#  'CD8-TEM',
#  'M',
#  'eosino',
#  'NK-adaptive',
#  'B-memory-IgM-MZ',
#  'TFH',
#  'carcinoma-cell',
#  'CD8-T_KLRG1pos-effector',
#  'abT',
#  'c-mono',
#  'CD4-T',
#  'leukocyte',
#  'gdT',
#  'B',
#  'TEM',
#  'ILC3-NCRneg',
#  'TRM',
#  'CD4-TRM',
#  'CD8-TRM',
#  'B-memory-DN',
#  'endo-aerocyte',
#  'B-pb-t3',
#  'TNK',
#  'cDC2',
#  'mast',
#  'mo-DC',
#  'CD8-T',
#  'nc-mono',
#  'lung-epi',
#  'Langerhans',
#  'CD56bright-NK',
#  'B-pb-t1',
#  'NK',
#  'CD8-T_KLRG1neg-effector',
#  'epi',
#  'FDC',
#  'smooth-muscle',
#  'CD4-TCM',
#  'plasma',
#  'ILC2',
#  'CD4-Teffector']

# %%
#plot the cell type hierarchy
G.plot_celltypes()
# Out:
# all celltypes in knowledge base: ['CD8-T_terminal-exhaustion', 'endo-arterial', 'ILC1', 'TCM', 'baso', 'T-naive', 'ILC', 'gran', 'cDC3', 'cDC', 'endo-lymphatic', 'ILC3-NCRpos', 'lung-endo-venous', 'Lti', 'CD8-TSCM', 'CD56dim-NK', 'neutro', 'lung-smooth-muscle', 'endo-systemic-venous', 'crc-carcinoma-cell', 'p-DC', 'B-memory-switched', 'all-cells', 'colon-epi', 'ILC3', 'CD4-TSCM', 'B-memory-non-switched', 'iNKT', 'capillary', 'CD4-TEM', 'GC-B', 'Mac', 'CD8-TCM', 'cDC1', 'B-naive', 'B-pb-mature', 'CD8-Teffector', 'CD8-T-progenitor-exhausted', 'TSCM', 'fibro', 'endo', 'T', 'DC', 'NSCLC-carcinoma-cell', 'B-pb-t2', 'B-memory', 'MAIT', 'plasma-blast', 'mono', 'Treg', 'MDC', 'CD8-TEM', 'M', 'eosino', 'NK-adaptive', 'B-memory-IgM-MZ', 'TFH', 'carcinoma-cell', 'CD8-T_KLRG1pos-effector', 'abT', 'c-mono', 'CD4-T', 'leukocyte', 'gdT', 'B', 'TEM', 'ILC3-NCRneg', 'TRM', 'CD4-TRM', 'CD8-TRM', 'B-memory-DN', 'endo-aerocyte', 'B-pb-t3', 'TNK', 'cDC2', 'mast', 'mo-DC', 'CD8-T', 'nc-mono', 'lung-epi', 'Langerhans', 'CD56bright-NK', 'B-pb-t1', 'NK', 'CD8-T_KLRG1neg-effector', 'epi', 'FDC', 'smooth-muscle', 'CD4-TCM', 'plasma', 'ILC2', 'CD4-Teffector']

# %%
#you can open this file using your browser (will not be displayed in colab)
G.plot_graph_interactive(attributes=['cell_type','cellular_process'],colors= ['red','blue'], save_path = 'graph.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# graph.html

# %%
# !ls
# Out:
# Cytopus_utils_tutorial.ipynb		  graph.html
# Hierarchical_annotation_tutorial.ipynb	  graph_attributes.csv
# KnowledgeBase_construct.ipynb		  graph_attributes_class_A.csv
# KnowledgeBase_queries_colaboratory.ipynb  graph_nodes.csv
# Utils_tutorial.ipynb			  hierarchy.csv
# cell_identities.gmt			  identities.csv
# cell_identities.tsv			  lib
# cellular_processes.gmt			  metadata.csv
# cumulative_downloads.ipynb		  output.csv
# gene_programs.gmt			  processes.csv
# gene_programs.tsv

# %%
#get parent in the hierarchy of specific cell type
list(G.graph.successors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['DC']

# %%
#get child in the hierarchy of a specific cell type
list(G.graph.predecessors('cDC')) #arrows are 'SUBSET_OF' not 'PARENT_OF' --> use successor to get parents
# Out:
# ['cDC1', 'cDC2', 'cDC3']

# %%
#get cell type markers
G.get_identities(['TNK'],include_subsets=True).keys()
# Out:
# dict_keys(['TCM', 'Treg', 'T-naive', 'TSCM', 'ILC1', 'NK-adaptive', 'TEM', 'CD56bright-NK', 'CD8-T_KLRG1pos-effector', 'CD4-T', 'CD56dim-NK', 'TRM', 'Lti', 'ILC3-NCRpos', 'abT', 'TFH', 'CD8-T_KLRG1neg-effector', 'ILC3-NCRneg', 'ILC2', 'gdT', 'NK', 'CD8-T'])

# %%
#dictionary of all cellular processes in KnowledgeBase as a dictionary {'process_1':['gene_a','gene_e','gene_y',...],'process_2':['gene_b','gene_u',...],...}
G.processes.keys()
# Out:
# dict_keys(['all_chondroitine-and-heparan-sulfate_synthesis', 'all_retinol_metabolism', 'all_RIG-I-like-receptor_signaling', 'leuko_transendothelial-migration', 'all_propanoate_metabolism', 'NSCLC-carcinoma-cell_TGFB1_response', 'all_p53-signaling', 'all_autophagy-selective', 'all_circadian-rhythm', 'all_VAL-LEU-ILE_metabolism', 'M_IL17A_response', 'all_taurine-hypotaurine_metabolism', 'B_IgM-ligation_response', 'all_microautophagy-lysosomal', 'all_transmembrane-transport-ER', 'all_macroautophagy_regulation_positive', 'all_TYR_metabolism', 'all_SASP', 'all_histone-methylation', 'all_TNF-via-NFkB_signaling', 'all_iron-uptake-and-storage', 'all_n-glycan_synthesis', 'all_transmembrane-transport-golgi', 'all_PHE_metabolism', 'Treg_FoxP3-stabilization', 'all_riboflavin_metabolism', 'all_polyamines_metabolism', 'all_PI3K-AKT-mTOR_signaling', 'all_inositol-phosphate_metabolism', 'all_DNA-demethylation', 'fibro_IL4_response', 'all_wnt-beta-catenin-signaling', 'M_mac_CSF1_response', 'all_lactate_production', 'T_IL4_response', 'all_complement_production', 'all_n-glycan_degradation', 'all_porphyrine-heme_metabolism', 'all_glycogenesis', 'all_heparan-sulfate_degradation', 'all_creatinine_metabolism', 'all_GPI-anchor_synthesis', 'all_type-II-ifn-response', 'all_glycogenolysis', 'all_G2M-transition', 'B_Breg_UP', 'fibro_BMP4_response', 'all_IL6-JAK-STAT3_signaling', 'all_MHC-II-presentation', 'all_hypoxia-response', 'all_biotin_metabolism', 'all_autophagy-of-mitochondria', 'all_urea-cycle', 'all_pyrimidine_metabolism', 'all_actin-cytoskeleton_regulation', 'all_nucleotide_metabolism', 'all_LYS_metabolism', 'all_type-I-ifn-response', 'lung-epi_TGFB1_response', 'all_autophagy-peroxisome', 'all_galactose_metabolism', 'CD4-T_TH17_UP', 'all_citric-acid-cycle', 'all_ubiquinone_synthesis', 'fibro_EGF_response', 'all_hedgehog_signaling', 'M_angiogenic-effectors', 'all_autophagy-of-mitochondria_regulation_positive', 'T_tcr-activation', 'all_macroautophagy', 'CD8-T_terminal-exhaustion', 'all_lipophagy', 'all_steroid_metabolism', 'all_unfolded-protein-response', 'all_thiamin_metabolism', 'all_GLU_metabolism', 'all_Beta-Ala_metabolism', 'all_hyaluronan_metabolism', 'all_mitophagy_regulation_positive', 'all_exocytosis', 'lung-epi_IL13_response', 'CD4-T_IL4_response', 'all_CYS_metabolism', 'CD8-T_progenitor-exhaustion_UP', 'lung-smooth-muscle_TGFB1_response', 'all_DNA-methylation', 'mast_granule-exocytosis', 'all_platelet-activation-factor_production', 'all_pyroptosis', 'all_ARG-PRO_metabolism', 'all_pentose-phosphate-pathway', 'all_glyoxylate-dicarboxylate_metabolism', 'neutro_CXCL8_response', 'all_NOTCH_signaling', 'all_protein-degradation-proteasome', 'all_mTORC1_signaling', 'fibro_IGF1_response', 'all_glycerophospholipid_metabolism', 'all_JAK-STAT_signaling', 'all_DNA-repair', 'all_glutathione_metabolism', 'all_cholesterol-homeostasis', 'all_peroxisome-component', 'all_MET_metabolism', 'all_nucleophagy-late', 'CD4-T_TH2_UP', 'all_pyrimidine_synthesis', 'all_transmembrane-transport-lysosome', 'CD4-T_TH9_UP', 'all_MYC_targets', 'Mac_IFNG_response', 'all_mitophagy', 'all_autophagy_regulation_positive', 'all_sphingolipid_metabolism', 'lung-epi_IL4_response', 'endo_VEGFC_response', 'all_fatty-acid-metabolism', 'all_triacylglycerol_synthesis', 'all_thrombolysis-factor_production', 'CD4-T_TH22_UP', 'TNK_cytotoxicity-effectors', 'all_amino-sugar-nucleotide-sugar_metabolism', 'all_cyclic-nucleotide_metabolism', 'all_keratan-sulfate_synthesis', 'all_mitotic-spindle-component', 'all_chondroitine-sulfate_degradation', 'Mac_CSF1_response', 'all_fructose-mannose_metabolism', 'all_fatty-acid-beta-oxidation-peroxisomal', 'Mac_IL4-IL13_response', 'CD8-T_IL12_response', 'all_phosphoinositide_signaling', 'TNK_IL2-STAT5-signaling', 'Mac_LPS_response', 'all_autophagy-chaperone-mediated', 'all_ascorbate-uptake', 'all_ketone-body_metabolism', 'all_keratan-sulfate_degradation', 'all_autophagic-cell-death', 'all_GABA-shunt', 'B_effector-2_UP', 'all_reticulophagy', 'all_MHC-I-p ...

# %%
#dictionary of all cellular identities in KnowledgeBase as a dictionary {'identity_1':['gene_j','gene_k','gene_z',...],'identity_2':['gene_y','gene_p',...],...}
G.identities.keys()
# Out:
# dict_keys(['TCM', 'Treg', 'T-naive', 'B-pb-t2', 'endo-lymphatic', 'TSCM', 'cDC1', 'ILC1', 'NK-adaptive', 'TEM', 'FDC', 'endo-systemic-venous', 'endo-aerocyte', 'CD56bright-NK', 'plasma-blast', 'CD8-T_KLRG1pos-effector', 'p-DC', 'mast', 'B-memory-DN', 'B-naive', 'CD4-T', 'B-pb-t3', 'B', 'B-pb-mature', 'Mac', 'gran', 'cDC2', 'CD56dim-NK', 'TRM', 'Lti', 'ILC3-NCRpos', 'abT', 'TFH', 'mono', 'CD8-T_KLRG1neg-effector', 'B-memory-IgM-MZ', 'cDC3', 'B-memory-switched', 'ILC3-NCRneg', 'Langerhans', 'mo-DC', 'endo-arterial', 'ILC2', 'plasma', 'B-pb-t1', 'lung-endo-venous', 'gdT', 'NK', 'capillary', 'CD8-T', 'B-memory', 'B-memory-non-switched', 'GC-B'])

# %%
#get genesets for a specific celltype
query_celltype = 'Treg'
gs_of_interest = [x[0] for x in G.filter_edges(attribute_name = 'class', attributes = ['process_OF'],target=query_celltype) if x[1]==query_celltype]
print('Gene sets directly related to celltype',query_celltype,'are:',gs_of_interest)
# Out:
# Gene sets directly related to celltype Treg are: ['Treg_FoxP3-stabilization']

# %%
#dictionary with gene set properties (for cellular processes or identities)

print('here external gene set from GO:')
print(G.graph.nodes['all_macroautophagy_regulation_positive'])

print('here manually curated gene set by the package author:')
print(G.graph.nodes['Mac_LPS_response'])
# Out:
# here external gene set from GO:
# {'version_id': 'v_hs209', 'author': 'GO Term 2019-01-01: 10.5281/zenodo.2529950_210828, 10.1038/75556,  10.1093/nar/gkaa1113', 'license': ' Creative Commons Attribution 4.0 Unported License', 'license_link': 'http://geneontology.org/docs/go-citation-policy/', 'license_type': 'c', 'gene_set_type': 'manual_external', 'gene_set_topic': 'cell_death_autophagy'}
# here manually curated gene set by the package author:
# {'version_id': 'v_hs230', 'author': 'wallet', 'license': 'MIT', 'license_link': 'https://github.com/wallet-maker/cytopus/blob/main/LICENSE', 'license_type': 'c', 'gene_set_type': 'bulk_curated', 'gene_set_topic': 'immune_cellular_response'}

# %% [markdown]
# The KnowledgeBase object can also store metadata about the gene sets. In our default knowledge bases this includes:
# '''
# 'version_id': str,  format: 'v_' + species in {hs, mm} for homo sapiens, mus musculus respectively + ascending int number,
# <br>
#  'author': str, acronym for author surname + first letter of first name,
#  <br>
#  'license': str, license type (e.g. MIT license)
#  <br>
#  'license_link': str, URL where original license can be found
#  <br>
#  'license_type': str, whether license allows commercial&non-commercial 'c', or non-commercial 'nc' use only.
#  <br>
#  'gene_set_type': str, whether the gene set was curated from literated 'curated', or curated from a perturbation experiment with RNA readout 'bulk_curated'
#  <br>
#  'gene_set_topic': str, general topic the gene set belong too
# <br>
# '''
#
# We provide the information to the best of our knowledge.
# However, we cannot guarantee that licensing information is accurate, it is in the resposibility of the authors to verify that this.

# %%
#access metadata for a specific gene set
G.graph.nodes['Mac_LPS_response']
# Out:
# {'version_id': 'v_hs230',
#  'author': 'wallet',
#  'license': 'MIT',
#  'license_link': 'https://github.com/wallet-maker/cytopus/blob/main/LICENSE',
#  'license_type': 'c',
#  'gene_set_type': 'bulk_curated',
#  'gene_set_topic': 'immune_cellular_response'}

# %%
#get genesets for a specific celltype
query_celltype = 'Treg'
gs_of_interest = [x[0] for x in G.filter_edges(attribute_name = 'class', attributes = ['process_OF'],target=query_celltype) if x[1]==query_celltype]
print('Gene sets directly related to celltype',query_celltype,'are:',gs_of_interest)
# Out:
# Gene sets directly related to celltype Treg are: ['Treg_FoxP3-stabilization']

# %% [markdown]
# # Create a dictionary for Spectra

# %%
#if necessary convert cell type names to names in the KnowledgeBase
#e.g. B_GC would be the name for germinal center B cells in your data 
#but in the KnowledgeBase they are stored with a hyphon 'GC-B'

conversion_dict = {'B_GC':'GC-B',
 'B_memory':'B-memory',
 'B_naive': 'B-naive',
 'CD4_T':'CD4-T',
 'CD8_T':'CD8-T',
 'DC':'DC',
 'ILC3':'ILC',
 'MDC':'Mac',
 'NK':'NK',
 'Treg':'Treg',
 'gdT':'gdT',
 'mast':'mast',
 'pDC':'p-DC',
 'plasma':'plasma'}

#to map KnowledgeBase labels back to labels in data
conversion_dict_inv = {}
for i,v in conversion_dict.items():
    conversion_dict_inv[v]=i
conversion_dict_inv['global'] = 'global'

# %%
#define cell types to retrieve gene sets for
celltype_of_interest = ['B_GC',
 'B_memory',
 'B_naive',
 'CD4_T',
 'CD8_T',
 'DC',
 'ILC3',
 'MDC',
 'NK',
 'Treg',
 'gdT',
 'mast',
 'pDC',
 'plasma']
global_celltypes = ['all-cells','leukocyte']

celltype_of_interest = [conversion_dict[x] for x in celltype_of_interest]

#you can retrieve gene sets linked to the parents and children of the queried gene sets above
#you can define the query depth using a dictionary, for all cell types not defined in the dict the query depth of the 
#<parent_depth> parameter will be used (proceed equivalently for children using the <child_depth> and <child_depth_dict>
#parameters)

query_depth_parent = {'NK':2,'Treg':None,'DC':None} #e.g. removing the query for parent gene sets for Treg here because this would add the
                                #T-helper polarization gene sets (TH1, TH2, TH22 etc)
query_depth_child = {'CD4-T':None,'ILC':None}

#retrieve dictionary for Spectra
G.get_celltype_processes(celltype_of_interest,global_celltypes = global_celltypes,get_children=True,get_parents=True,
                         child_depth=1,parent_depth=1,parent_depth_dict = query_depth_parent,
                        child_depth_dict = query_depth_child)
# Out:
# cell types of interest share the following children: ['p-DC'] This may be desired.
# cell types of interest share the following parents: ['B', 'abT', 'DC', 'ILC', 'TNK', 'M'] This may be desired.

# %%
#convert celltype labels back to celltypes in data
Spectra_dict = {}

for i,v in G.celltype_process_dict.items():
    Spectra_dict[conversion_dict_inv[i]] = v

# %%
Spectra_dict.keys()
# Out:
# dict_keys(['B_GC', 'B_memory', 'B_naive', 'CD4_T', 'CD8_T', 'DC', 'ILC3', 'MDC', 'NK', 'Treg', 'gdT', 'mast', 'pDC', 'plasma', 'global'])

# %%
Spectra_dict['CD4_T'].keys()
# Out:
# dict_keys(['CD4-T_TH17_UP', 'CD4-T_IL4_response', 'CD4-T_TH2_UP', 'CD4-T_TH9_UP', 'CD4-T_TH22_UP', 'CD4-T_IL12_response', 'T_IL4_response', 'T_tcr-activation', 'T_IL21_response'])

# %% [markdown]
# ## Write dictionary to .json file

# %%
#store Spectra dictionary

import json
jpath = 'Spectra_dict.json'

with open(jpath, 'w') as f:
    json.dump(Spectra_dict,f)
print('saved data to:',jpath)
# Out:
# saved data to: Spectra_dict.json

# %%
#load Spectra dictionary

import json
jpath = 'Spectra_dict.json'
f = open(jpath, 'r')
Spectra_dict = json.loads(f.read())
